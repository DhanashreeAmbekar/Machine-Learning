# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %%
import pandas as pd
df=pd.read_csv("D:/Machine-Learning/1.Simple Linear Regression/50_Startups.csv")

# %%
df
# Out:
#           RND      ADMIN        MKT       STATE     PROFIT
# 0   165349.20  136897.80  471784.10    New York  192261.83
# 1   162597.70  151377.59  443898.53  California  191792.06
# 2   153441.51  101145.55  407934.54     Florida  191050.39
# 3   144372.41  118671.85  383199.62    New York  182901.99
# 4   142107.34   91391.77  366168.42     Florida  166187.94
# 5   131876.90   99814.71  362861.36    New York  156991.12
# 6   134615.46  147198.87  127716.82  California  156122.51
# 7   130298.13  145530.06  323876.68     Florida  155752.60
# 8   120542.52  148718.95  311613.29    New York  152211.77
# 9   123334.88  108679.17  304981.62  California  149759.96
# 10  101913.08  110594.11  229160.95     Florida  146121.95
# 11  100671.96   91790.61  249744.55  California  144259.40
# 12   93863.75  127320.38  249839.44     Florida  141585.52
# 13   91992.39  135495.07  252664.93  California  134307.35
# 14  119943.24  156547.42  256512.92     Florida  132602.65
# ...

# %%
df.head()
# Out:
#          RND      ADMIN        MKT       STATE     PROFIT
# 0  165349.20  136897.80  471784.10    New York  192261.83
# 1  162597.70  151377.59  443898.53  California  191792.06
# 2  153441.51  101145.55  407934.54     Florida  191050.39
# 3  144372.41  118671.85  383199.62    New York  182901.99
# 4  142107.34   91391.77  366168.42     Florida  166187.94

# %%
X = df[["ADMIN"]]
Y = df[["PROFIT"]]

# %%
X.head()
# Out:
#        ADMIN
# 0  136897.80
# 1  151377.59
# 2  101145.55
# 3  118671.85
# 4   91391.77

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
import seaborn as sns
sns.scatterplot(data=df, x="ADMIN", y="PROFIT")
# Out:
# <Axes: xlabel='ADMIN', ylabel='PROFIT'>

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X, Y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([76974.47130542])

# %%
model.coef_
# Out:
# array([[0.2887492]])

# %%
sns.regplot(data = df, x="ADMIN", y="PROFIT", line_kws={"color":"red"})
# Out:
# <Axes: xlabel='ADMIN', ylabel='PROFIT'>

# %%
sns.pairplot(data=df)

# %%
ypred = model.predict(X)
ypred[0:5]
# Out:
# array([[116503.6018596 ],
#        [120684.62967237],
#        [106180.1681897 ],
#        [111240.87333494],
#        [103363.77199475]])

# %%
Y.head()
# Out:
#       PROFIT
# 0  192261.83
# 1  191792.06
# 2  191050.39
# 3  182901.99
# 4  166187.94

# %%
from sklearn.metrics import (
    root_mean_squared_error,
    mean_absolute_error,
    mean_absolute_percentage_error,
    r2_score
)

# %%
def evaluate_model(model, x, y):
    # Predict the results for x
    ypred = model.predict(x)
    # Evaluate the metrics
    rmse = root_mean_squared_error(y, ypred)
    mae = mean_absolute_error(y, ypred)
    mape = mean_absolute_percentage_error(y, ypred)
    r2 = r2_score(y, ypred)
    # Print the metrics
    print(f"RMSE : {rmse:.2f}")
    print(f"MAE : {mae:.2f}")
    print(f"MAPE : {mape:.4f}")
    print(f"R2 Score : {r2:.4f}")

# %%
evaluate_model(model, X, Y)
# Out:
# RMSE : 39089.07
# MAE : 30659.81
# MAPE : 0.4353
# R2 Score : 0.0403

# %% [markdown]
# ### From above r2 score is 0.0403 < 0.8 hence it is a not good model and cannot be used for out of sample predictions

# %%
# out of sample prediction

X.values[0:5]
# Out:
# array([[136897.8 ],
#        [151377.59],
#        [101145.55],
#        [118671.85],
#        [ 91391.77]])

# %%
admin = [[1_55_000]]
model.predict(admin)
# Out:
# array([[121730.59767048]])

# %%
76974.47 + 0.2887*155000
# Out:
# 121722.97

# %% [markdown]
# ### If RND increases by 1 unit Profit will increase by 0.2887

# %% [markdown]
# ### If RND increases by 1000 unit Profit will increase by 287.4
